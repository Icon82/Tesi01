# %% [markdown]
# <a href="https://colab.research.google.com/github/Icon82/Tesi01/blob/main/Tesi01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/WHOCancers.csv')

# %%
df
# Out:
#        Region Code Region Name Country Code  Country Name  Year      Sex  \
# 0               EU      Europe          ALB       Albania  1987      All
# 1               EU      Europe          ALB       Albania  1987      All
# 2               EU      Europe          ALB       Albania  1987      All
# 3               EU      Europe          ALB       Albania  1987      All
# 4               EU      Europe          ALB       Albania  1987      All
# ...            ...         ...          ...           ...   ...      ...
# 304201          AF      Africa          ZAF  South Africa  2015  Unknown
# 304202          AF      Africa          ZAF  South Africa  2015  Unknown
# 304203          AF      Africa          ZAF  South Africa  2015  Unknown
# 304204          AF      Africa          ZAF  South Africa  2015  Unknown
# 304205          AF      Africa          ZAF  South Africa  2015  Unknown
#
#        Age group code  Age Group  Number  Percentage total deaths  \
# ...

# %%
grpanno=df[["Year","Number"]].groupby(["Year"]).sum()

# %%
plt.figure(figsize=(10,6))
plt.plot(grpanno['Number'])

plt.title('Titolo del Grafico')
plt.ylabel('Numero decessi')
plt.xlabel('Anno')
# Out:
# Text(0.5, 0, 'Anno')
